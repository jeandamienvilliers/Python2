# %% [markdown]
# # Exercises: Reading and Writing Files

# %% [markdown]
# ### Exercise 1
# 1/ Create a program that will write todays date into a file – the name of the file can be hard coded or supplied by the user. You can use the datetime.date.today()
# function to obtain the current date and time. You can use the str() function to
# convert this date time object into a string so that it can be written out to a file
#
# 2/ Create a second program to reload the date from the file and convert the string
# into a date object. You can use the datetime.strptime() function to
# convert a string into a date time object (ex: datetime_object = datetime.strptime(date_str, '%Y-%m-%d
# %H:%M:%S.%f'))

# %% [markdown]
# ## Exercise 2
#
# Create a function create_today_directory() which checks if a folder with the date of today (yyy-mm-dd) is in the current working directory. If the folder is missing, the function creates the required folder.
